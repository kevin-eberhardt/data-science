# %% [markdown]
# # Data Exploration

# %%
import sys
import os
from dotenv import load_dotenv

# load environment variables
load_dotenv()

#add working directory to sys path to execute utils/dataset.py
working_dir = os.environ.get("WORKING_DIRECTORY")
sys.path.insert(0, working_dir)

# %%
from utils.dataset import get_data 

df = get_data()
df.head()
# Out:
# Loading data from wines: 8000it [00:00, 35461.78it/s]
#     wine type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  Pinot noir            5.8              0.15         0.49             1.1
# 1      Merlot            6.6              0.25         0.32             5.6
# 2  Chardonnay            6.7              0.21         0.34             1.5
# 3      Merlot            8.3              0.28         0.27            17.5
# 4      Merlot            7.5              0.42         0.19             6.9
#
#    magnesium  flavanoids    minerals  calcium  chlorides  free sulfur dioxide  \
# 0  76.729301      894.94  186.639301   109.91      0.048                 21.0
# 1   4.795712     1160.95  251.875712   247.08      0.039                 15.0
# 2  85.193710      789.82  304.703710   219.51      0.035                 45.0
# 3  11.976525      777.86  237.586525   225.61      0.045                 48.0
# ...

# %%
#EDA - Exploratory Data Analysis - Data Exploration - Data Visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns




#Exploratory Data Analysis
def eda(dataframe):
    # Shape of the data
    print("Number of rows: ", dataframe.shape[0])
    print("Number of columns: ", dataframe.shape[1])
    
    # Summary statistics
    print("\nSummary Statistics:")
    print(dataframe.describe())
    
    # Missing values
    print("\nMissing Values:")
    print(dataframe.isnull().sum())
    
    # Categorical features
    print("\nCategorical Features:")
    print(dataframe.select_dtypes(include=['object']).nunique())
    
    # Histogram for all numeric columns
    # make it large enough to see the plot clearly
    dataframe.hist(figsize=(20, 20), bins=50, xlabelsize=8, ylabelsize=8)
    
    # Correlation matrix
    # make it large enough to see the plot clearly
    plt.figure(figsize=(20, 20))
    sns.heatmap(dataframe.corr(), annot=True, fmt=".2f")
    plt.show()

    # Outliers - Boxplot
    # make it large enough to see the plot clearly
    plt.figure(figsize=(20, 20))
    dataframe.boxplot()
    plt.show()




    


eda(df)
# Out:
# Cannot remove outliers from wine type because it is not numeric.
# Number of rows:  7392
# Number of columns:  17
#
# Summary Statistics:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    7392.000000       7392.000000  7386.000000     7384.000000
# mean        6.859727          0.278749     0.334885        6.432665
# std         0.836112          0.100550     0.121339        5.147078
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        10.700000          1.100000     1.230000       65.800000
#
#          magnesium   flavanoids     minerals      calcium    chlorides  \
# count  7384.000000  7384.000000  7384.000000  7384.000000  7384.000000
# mean     49.403279   933.682486   285.832193   236.428914     0.046284
# ...
